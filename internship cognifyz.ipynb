# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# LEVEL-1:
#
# TASK- 1: Data Overview

# %%
data=pd.read_csv("/content/drive/MyDrive/internship cognifyz/Data_set 2.csv")
data.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
data.shape
# Out:
# (40, 24)

# %%
data.isna().sum()
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
data.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
data.describe(include="object")
# Out:
#        gender Investment_Avenues Stock_Marktet   Factor             Objective  \
# count      40                 40            40       40                    40
# unique      2                  2             2        3                     3
# top      Male                Yes           Yes  Returns  Capital Appreciation
# freq       25                 37            35       25                    26
#
#                 Purpose   Duration Invest_Monitor   Expect       Avenue  \
# count                40         40             40       40           40
# unique                3          4              3        3            4
# top     Wealth Creation  3-5 years        Monthly  20%-30%  Mutual Fund
# freq                 32         19             29       32           18
#
#        What are your savings objectives?         Reason_Equity  \
# count                                 40                    40
# unique                                 3                     3
# ...

# %% [markdown]
# LEVEL-1:Beginner
#
# TASK-2: Gender Distribution **bold text**

# %%
data_gender=data["gender"]
data_gender.head(10)
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# 5    Female
# 6    Female
# 7      Male
# 8      Male
# 9      Male
# Name: gender, dtype: object

# %%
dg=data_gender.value_counts().reset_index()
dg.columns=["Gender","Count"]
dg
# Out:
#    Gender  Count
# 0    Male     25
# 1  Female     15

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.bar(dg["Gender"],dg["Count"],label=dg["Gender"],color=["lightgreen","lightblue"])
plt.xlabel("Gender",color="red")
plt.ylabel("Count",color="red",)
plt.title("Gender Distribution",)
plt.legend(loc="upper right",)


plt.subplot(1,2,2)
plt.pie(dg["Count"],labels=dg["Gender"],autopct="%0.2f%%",colors=["lightgreen","lightblue"],shadow=1,explode=(0.08,0.0),startangle=105)
plt.legend(loc="upper right",)
plt.title("Gender Distribution",)
plt.show()

# %%
sns.countplot(x=data['age'],edgecolor="black",linewidth=2,color='lightgreen')
plt.title("Age Distribution",)
plt.xlabel("Age",color="black",)
plt.ylabel("Count",color="black",)
plt.show()

# %%
sns.countplot(x=data['Duration'],hue=data['gender'],hue_order=['Male','Female'],edgecolor="black",linewidth=2,palette='viridis')
plt.title("Duration Distribution",)
plt.xlabel("Duration",color="black",)
plt.ylabel("Count",color="black",)
plt.show()

# %%
sns.countplot(x=data['Avenue'],hue=data['gender'],edgecolor="black",linewidth=2,palette='viridis')
plt.title("Investment Avenue Distribution",)
plt.xlabel("Investment Avenue",color="black",)
plt.xticks(rotation=90)
plt.ylabel("Count",color="black",)
plt.show()

# %%
sns.countplot(x=data['Factor'],hue=data['gender'],edgecolor="black",linewidth=2,palette='viridis')
plt.title("Factor Distribution",)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.countplot(x=data['gender'],hue=data['Investment_Avenues'],edgecolor="black",linewidth=2,palette='viridis')
plt.title("Investment Avenues",)
plt.xlabel("Investment Avenues",color="black",)

plt.subplot(1,2,2)
sns.countplot(x=data['gender'],hue=data['Stock_Marktet'],edgecolor="black",linewidth=2,palette='viridis')
plt.title("Stock Market",)
plt.xlabel("Stock Market",color="black",)
plt.show()

# %%
sns.countplot(x=data['Duration'],hue=data['Invest_Monitor'],edgecolor="black",linewidth=2,palette='viridis')


plt.xlabel("Duration",color="black",)
plt.show()

# %% [markdown]
# Level 2: Intermediate
#
# Task 3: Descriptive Statistics

# %%
data_numeric=data.select_dtypes(exclude="object")

# %%
data_numeric["age"].median()
# Out:
# 27.0

# %%
data_numeric.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %% [markdown]
# Level 2: Intermediate
#
# Task 4: Most Preferred Investment Avenue

# %%
data_avenue=data['Avenue'].value_counts().reset_index()
data_avenue.columns=["Avenue","Count"]
data_avenue
# Out:
#                   Avenue  Count
# 0            Mutual Fund     18
# 1                 Equity     10
# 2         Fixed Deposits      9
# 3  Public Provident Fund      3

# %%
frequency=data["Avenue"].value_counts()
most_preferred_avenue=frequency.idxmax()
print(f'The investment avenue with the highest frequency is: {most_preferred_avenue}')
# Out:
# The investment avenue with the highest frequency is: Mutual Fund

# %%
plt.figure(figsize=(8,4))
plt.bar(data_avenue["Avenue"],data_avenue["Count"],label=data_avenue["Avenue"],color=["lightgreen","lightblue","lightpink","lightcoral"],edgecolor='black',linewidth=2,align="center")

plt.xlabel("Avenue",color="black",)
plt.ylabel("Count",color="black",)
plt.title("Most Preferred Investment Avenue",)

plt.legend(loc="upper right",)
plt.show()

# %%
data_age=data["age"].value_counts().reset_index()
data_age.columns=["age","Count"]
data_age
# Out:
#     age  Count
# 0    27      7
# 1    29      5
# 2    31      4
# 3    26      4
# 4    30      3
# 5    24      3
# 6    25      3
# 7    34      2
# 8    21      2
# 9    35      2
# 10   28      2
# 11   23      1
# 12   22      1
# 13   32      1

# %% [markdown]
# Level 3: Advanced
#
# Task 6: Savings Objectives

# %%
#create a list of saving objectives

saving_obj=data["What are your savings objectives?"].dropna().unique()
print(f'The unique savings objectives are: {saving_obj}')
# Out:
# The unique savings objectives are: ['Retirement Plan' 'Health Care' 'Education']

# %%
#Description of saving objectives
saving_obj_description={'Retirement Plan':'Saving for retirement to ensure financial security in later years.',
                        'Health Care':'Setting aside funds to cover medical expenses, both expected and unexpected, including routine check-ups, medications and other healthcare needs.',
                        'Education':"Saving for children's education or personal educational goals."}

for obj in saving_obj_description:
  print(f'Objective: {obj}')
  print(f'Description: {saving_obj_description[obj]}')
# Out:
# Objective: Retirement Plan
# Description: Saving for retirement to ensure financial security in later years.
# Objective: Health Care
# Description: Setting aside funds to cover medical expenses, both expected and unexpected, including routine check-ups, medications and other healthcare needs.
# Objective: Education
# Description: Saving for children's education or personal educational goals.

# %%
data['age_group']=pd.cut(data['age'],bins=[0,20,25,30,35,40],labels=['<=20','21-25','26-30','31-35','35-40'],right=False)
grouped=data.groupby(by=[data['age_group'],data["What are your savings objectives?"]]).size().unstack().fillna(0)
grouped
# Out:
# What are your savings objectives?  Education  Health Care  Retirement Plan
# age_group
# <=20                                       0            0                0
# 21-25                                      1            2                4
# 26-30                                      2            8               11
# 31-35                                      0            3                7
# 35-40                                      0            0                2

# %%
plt.figure(figsize=(6,4))
var=sns.heatmap(data=grouped,annot=True,cmap="viridis",linewidths=0.5,linecolor='grey',cbar=True,fmt="d",square=False)

var.set(xlabel=("Savings Objectives"),ylabel=("Age Group"),title=("Savings Objectives by Age Group"))

plt.show()

# %% [markdown]
# Level 4: Expert
#
# Task 7: Common Information Sources

# %%
# Most common source of informations
df=data['Source'].value_counts().reset_index()
df.columns=[['source','count']]
df
# Out:
#                      source count
# 0     Financial Consultants    16
# 1  Newspapers and Magazines    14
# 2                Television     6
# 3                  Internet     4

# %%
plt.figure(figsize=(6,4))
sns.countplot(data['Source'],edgecolor="black",linewidth=2,color='lightgreen',)
plt.title("Common Information Sources",)

plt.show()

# %% [markdown]
# Level 4: Expert
#
# Task 8: Investment Duration
#
# Objective: Calculate the average investment
# duration.

# %%
def duration_midpoint(Duration):
  if Duration == 'Less than 1 year':
    return 0.5
  if Duration == '1-3 years':
    return 2
  if Duration == '3-5 years':
    return 4
  if Duration == 'More than 5 years':
    return 6
  return None

data["Duration_midpoint"]= data["Duration"].apply(duration_midpoint)

# %%
df_statistic=statistics.mean(data['Duration_midpoint'])
print(f'The average investment duration is {df_statistic:.2f} years.')

# df_statistic=statistics.median(data['Duration_midpoint'])
# print(f'The median of investment duration is {df_statistic:.2f} years.')

# df_statistic=statistics.mode(data['Duration_midpoint'])
# print(f'The mode of investment duration is {df_statistic:.2f} years.')

# df_statistic=statistics.stdev(data['Duration_midpoint'])
# print(f'The standard deviation from an sample of data of investment duration is {df_statistic:.2f} years.')

# df_statistic=statistics.variance(data['Duration_midpoint'])
# print(f'The variance of investment duration is {df_statistic:.2f} years.')
# Out:
# The average investment duration is 2.98 years.

# %% [markdown]
# Level 4: Expert
#
# Task 9: Expectations from Investments
#
# Objective: Summarize participants' expectations
# from investments.

# %%
expectations_counts= data['Expect'].value_counts().reset_index()
expectations_counts.columns=['Expect','Count']
print("Participant's expectation from investment\n")
expectations_counts
# Out:
# Participant's expectation from investment
#     Expect  Count
# 0  20%-30%     32
# 1  30%-40%      5
# 2  10%-20%      3

# %%
expectations_list=expectations_counts.index.to_list()
expectations_descriptions={
    '10%-20%': "Participant's expect return is between 10% and 20%",
    '20%-30%': "Participant's expect return is between 20% and 30%",
    '30%-40%': "Participant's expect return is between 30% and 40%",
}

expectations_counts['Description'] = expectations_counts['Expect'].map(expectations_descriptions)
print(expectations_counts)
# Out:
#     Expect  Count                                        Description
# 0  20%-30%     32  Participant's expect return is between 20% and...
# 1  30%-40%      5  Participant's expect return is between 30% and...
# 2  10%-20%      3  Participant's expect return is between 10% and...

# %% [markdown]
# Level 4: Expert
#
# Task 10: Correlation Analysis

# %%
# Mapping Expect to numeric values

mapping={'10%-20%': '15','20%-30%': '25','30%-40%': '35'}


data['Expect_return']=data['Expect'].map(mapping).astype(float)
data['Expect_return'].head(10)
# Out:
# 0    25.0
# 1    25.0
# 2    25.0
# 3    15.0
# 4    25.0
# 5    35.0
# 6    25.0
# 7    25.0
# 8    25.0
# 9    35.0
# Name: Expect_return, dtype: float64

# %%
# Calculate correlation matrix
corr=data[["Duration_midpoint",'age','Expect_return','Mutual_Funds','Equity_Market','Debentures','Government_Bonds','Fixed_Deposits','PPF','Gold']].corr()

# Display the correlation matrix
corr
# Out:
#                    Duration_midpoint       age  Expect_return  Mutual_Funds  \
# Duration_midpoint           1.000000  0.051756       0.258223      0.184528
# age                         0.051756  1.000000      -0.089606     -0.123914
# Expect_return               0.258223 -0.089606       1.000000      0.042828
# Mutual_Funds                0.184528 -0.123914       0.042828      1.000000
# Equity_Market               0.471251  0.246840       0.103172      0.332043
# Debentures                  0.034367  0.326638       0.459001     -0.351495
# Government_Bonds           -0.288315 -0.093632       0.237193     -0.114198
# Fixed_Deposits             -0.191524 -0.033685      -0.417172     -0.031604
# PPF                        -0.188376 -0.263167      -0.107989     -0.193665
# Gold                        0.201021 -0.057952      -0.296500     -0.401830
#
#                    Equity_Market  Debentures  Government_Bonds  \
# Duration_midpoint       0.471251    0.034367         -0.288315
# ...

# %% [markdown]
# The correlation matrix shows the following relationships between the selected columns:
#
# Age and Investment Duration: 0.052
#
# Age and Expected Returns: 0.026
#
# Investment Duration and Expected Returns: 0.179
#
# These correlations are relatively low, indicating weak linear relationships between these variables.

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
sns.scatterplot(x=data['Duration'],y=data['Expect'],data=corr,hue=data['gender'],edgecolor="black",linewidth=1,)
plt.title('Duration v/s Expected Returns')

plt.subplot(2,2,2)
sns.scatterplot(x=data['Duration'],y=data['age'],data=corr,hue=data['gender'],edgecolor="black",linewidth=1,)
plt.title('Age v/s Duration')

plt.subplot(2,2,3)
sns.scatterplot(y=data['age'],x=data['Expect'],data=corr,hue=data['gender'],edgecolor="black",linewidth=1,)
plt.title('Age v/s Expected Returns')

plt.show()

# %%
# Heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
plt.title('Correlation Heatmap')

sns.heatmap(data=corr,annot=True,cmap="viridis",linewidths=0.9,linecolor='grey',cbar=True,fmt="0.2f",square=False,)
plt.show()
